# %%
import pandas as pd
from tqdm.notebook import tqdm_notebook as tqdm
import datetime as dt

import numpy as np

import warnings
warnings.filterwarnings('ignore')

pd.set_option('max_column', None)
tqdm.pandas()

# %% [markdown]
# # Motivation

# %%
df1 = pd.concat([pd.read_csv(f'MSAP_part{i}.csv', index_col=0) for i in range(1, 4)])

# %%
df1.isnull().sum(axis=0)
# Out:
# ID_Operation_History           0
# DATE_REPORT                    0
# DATE_REPORT_SRC                0
# DATE_MONTH                     0
# EMPLOYEE_FIO              962347
# EMPLOYEE_ID              3008687
# EMPLOYEE_POSITION        3009508
# EBIRTH                   3027042
# RBEGDA                   3015450
# RENDDA                   3015450
# TB_ID                          0
# urf_code_uni                2728
# SOURCE_SYSTEM             357210
# OPERATION                  21881
# QUANTITY                     172
# CHANNEL_GR               3174465
# IS_FRAUD                       0
# DESCRIPTION               450765
# insert_date               450765
# IN_MOTIV                       0
# PRODUCT_NAME               21881
# vl_up                    5172088
# DATE_UPDATE                    0
# PAYMENT_STATUS           8551378
# epk_id                         0
# untb                       47429
# fullname                   47429
# birth                      47429
# Табельный_клиента       13219207
# Отпуск                  12365398
# dtype: int64

# %%
df1.dtypes
# Out:
# ID_Operation_History      int64
# DATE_REPORT              object
# DATE_REPORT_SRC          object
# DATE_MONTH               object
# EMPLOYEE_FIO             object
# EMPLOYEE_ID             float64
# EMPLOYEE_POSITION        object
# EBIRTH                   object
# RBEGDA                   object
# RENDDA                   object
# TB_ID                     int64
# urf_code_uni             object
# SOURCE_SYSTEM            object
# OPERATION                object
# QUANTITY                 object
# CHANNEL_GR               object
# IS_FRAUD                  int64
# DESCRIPTION              object
# insert_date              object
# IN_MOTIV                  int64
# PRODUCT_NAME             object
# vl_up                    object
# DATE_UPDATE              object
# PAYMENT_STATUS           object
# epk_id                    int64
# untb                    float64
# fullname                 object
# birth                    object
# Табельный_клиента       float64
# Отпуск                   object
# dtype: object

# %% [markdown]
# ### Убираем нулевые значения и переводим в нужный формат

# %%
df1.loc[(df1['RENDDA'] > '2023-01-01'), 'RENDDA'] = '2262-1-1'

# %%
df1['EBIRTH'] = df1['EBIRTH'].fillna('1700-1-1')
df1['RBEGDA'] = df1['RBEGDA'].fillna('1700-1-1')
df1['RENDDA'] = df1['RENDDA'].fillna('2262-1-1')
df1['insert_date'] = df1['insert_date'].fillna('1700-1-1')
df1['DATE_UPDATE'] = df1['DATE_UPDATE'].fillna('1700-1-1')

# %%
df1 = df1.fillna({
    'EMPLOYEE_FIO':'-',
    'EMPLOYEE_POSITION': '-',
    'urf_code_uni': '-',
    'SOURCE_SYSTEM': '-',
    'OPERATION': '-',
    'QUANTITY': 1,
    'CHANNEL_GR': '-',
    'DESCRIPTION': '-',
    'PRODUCT_NAME': '-',
    'vl_up': 0,
    'fullname': '~'
})

# %%
df1['DATE_REPORT'] = pd.to_datetime(df1['DATE_REPORT']).dt.date
df1['EBIRTH'] = pd.to_datetime(df1['EBIRTH']).dt.date
df1['RBEGDA'] = pd.to_datetime(df1['RBEGDA']).dt.date
df1['RENDDA'] = pd.to_datetime(df1['RENDDA']).dt.date
df1['insert_date'] = pd.to_datetime(df1['insert_date']).dt.date
df1['DATE_UPDATE'] = pd.to_datetime(df1['DATE_UPDATE']).dt.date
df1['birth'] = pd.to_datetime(df1['birth']).dt.date
df1['DATE_MONTH'] = pd.to_datetime(df1['DATE_MONTH'])
#df1 = df1.astype({'untb':'Int64', 'EMPLOYEE_ID': 'Int64'})

# %% [markdown]
# ### Смотрим некоторые категориальные признаки и их значения

# %%
df1['EMPLOYEE_POSITION'].value_counts()
# Out:
# СТАРШИЙ КЛИЕНТСКИЙ МЕНЕДЖЕР                 6734647
# КЛИЕНТСКИЙ МЕНЕДЖЕР                         1020731
# СТАРШИЙ МЕНЕДЖЕР ПО ОБСЛУЖИВАНИЮ             819626
# РУКОВОДИТЕЛЬ ОФИСА                           813090
# ЗАМЕСТИТЕЛЬ РУКОВОДИТЕЛЯ ОФИСА               283180
# КОНСУЛЬТАНТ                                  175356
# КЛИЕНТСКИЙ МЕНЕДЖЕР ПРЕМЬЕР                  116166
# МЕНЕДЖЕР ПО СЕРВИСУ                           72622
# ФИНАНСОВЫЙ МЕНЕДЖЕР                           60537
# СТ.МЕНЕДЖЕР ПО ИПОТЕЧНОМУ КРЕДИТОВАНИЮ        39027
# ВЕДУЩИЙ МЕНЕДЖЕР ПО ОБСЛУЖИВАНИЮ              33678
# МЕНЕДЖЕР ПО ИПОТЕЧНОМУ КРЕДИТОВАНИЮ           33375
# КОНСУЛЬТАНТ ПО РАБОТЕ С ПФР                   33294
# СПЕЦИАЛИСТ                                    27207
# СТАРШИЙ СПЕЦИАЛИСТ                            17194
# СТАРШИЙ МЕНЕДЖЕР ПО СЕРВИСУ                   17117
# МЕНЕДЖЕР ПО СДЕЛКАМ С НЕДВИЖИМОСТЬЮ           14696
# СТ. МЕНЕДЖЕР ПО СДЕЛКАМ С НЕДВИЖИМОСТЬЮ       12922
# ОПЕРАЦИОННЫЙ МЕНЕДЖЕР                         12239
# МЕНЕДЖЕР ПО ПРОДАЖАМ                          10072
# МЕНЕДЖЕР ПО ОБСЛУЖИВАНИЮ                       8852
# АССИСТЕНТ КЛИЕНТСКОГО МЕНЕДЖЕРА ПРЕМЬЕР        8560
# ВЕДУЩИЙ СПЕЦИАЛИСТ ПО ОБСЛ.КОРП.КЛИЕНТОВ       4827
# РУКОВОДИТЕЛЬ ПРЕМЬЕР ОФИСА                     4159
# СПЕЦИАЛИСТ ПО ПРЯМЫМ ПРОДАЖАМ                  3188
# МЕНЕДЖЕР ПО ОБСЛУЖИВАНИЮ ИПОТЕЧ.КРЕДИТОВ       1869
# РУКОВОДИТЕЛЬ ОФИСОВ ИПОТЕЧНОГО КРЕДИТОВ.       1477
# СТАРШИЙ КЛИЕНТСКИЙ МЕНЕДЖЕР ПРЕМЬЕР            1114
# СТАРШИЙ ОПЕРАЦИОННЫЙ МЕНЕДЖЕР                  1075
# МОБИЛЬНЫЙ КЛИЕНТСКИЙ МЕНЕДЖЕР ПРЕМЬЕР          1071
#                                              ...
# ВЕДУЩИЙ СПЕЦИАЛИСТ                                8
# МЕНЕДЖЕР ПО ПРОДАЖАМ ПРОДУКТОВ КАНАЛА             8
# РУКОВОДИТЕЛЬ ПО ВНЕДРЕНИЮ ПРОЕКТОВ                8
# РУК-ЛЬ ГРУППЫ МАЛОЙ И МОБИЛЬНОЙ СЕТИ              8
# СП-СТ ПО СЕРВИС.ПОДДЕРЖ. ПР-ТОВ ЭКВ-ГА            7
# СТАРШИЙ СПЕЦИАЛИСТ ПО ВЗЫСКАНИЮ                   7
# РУКОВОДИТЕЛЬ ЗОНЫ ПО ОБСЛУЖ.ЗНАЧИМЫХ КЛ.          6
# СТАРШИЙ КРЕДИТНЫЙ АНАЛИТИК                        6
# ВЕД.СПЕЦ.СУДЕБНОГО И ИСПОЛНИТ.ПРОИЗВ-ВА           6
# МЕНЕДЖЕР ПО ПОДДЕРЖКЕ ПРОДАЖ СЛОЖН.ПРОД.          5
# ВЕДУЩИЙ СПЕЦИАЛИСТ ПО ВЗЫСКАНИЮ                   4
# КОНТРОЛЕР-КАССИР                                  3
# ЭКСПЕРТ ПО СОПРОВОЖДЕНИЮ АККРЕДИТАЦИИ             3
# ИНВЕСТИЦИОННЫЙ ТРЕНЕР                             3
# ГЛАВНЫЙ СПЕЦИАЛИСТ ПО ВЗЫСКАНИЮ                   2
# РУКОВОДИТЕЛЬ ГРУППЫ                               2
# ГЛ.СПЕЦ.СУДЕБНОГО И ИСПОЛНИТ.ПРОИЗВ-ВА            2
# РУКОВОДИТЕЛЬ ЦЕНТРА ПЕРСОНАЛЬНОГО ОБСЛУЖ          1
# ТЕРРИТОРИАЛЬНЫЙ ОПЕРАЦИОННЫЙ МЕНЕДЖЕР             1
# ДИСТАНЦИОННЫЙ КЛИЕНТСКИЙ МЕНЕДЖЕР ГРУППЫ          1
# ТЕР.МЕНЕДЖЕР ПО РАБОТЕ С ПАРТНЕРАМИ               1
# ПЕРСОНАЛЬНЫЙ МЕНЕДЖЕР                             1
# ТЕР.МЕН-Р ПО ИНВЕСТ.-БРОКЕР. ОБСЛ.                1
# МЕНЕДЖЕР НАПРАВЛЕНИЯ                              1
# КРЕДИТНЫЙ МЕНЕДЖЕР                                1
# ТЕРРИТОРИАЛЬНЫЙ МЕНЕДЖЕР ПО ИПОТ.КРЕДИТ.          1
# РЕГИОНАЛЬНЫЙ МЕНЕДЖЕР ПО ПРОДАЖАМ                 1
# НАЧ.ОТДЕЛА-РЕГ.РУК-ЛЬ ВНЕШ.ДИСТРИБУЦИИ            1
# ВЫЕЗДНОЙ КЛИЕНТСКИЙ МЕНЕДЖЕР                      1
# СТ.СПЕЦ.СУДЕБНОГО И ИСПОЛНИТ.ПРОИЗВ-ВА            1
# Name: EMPLOYEE_POSITION, Length: 101, dtype: int64

# %%
df1['SOURCE_SYSTEM'].unique()
# Out:
# array(['АС МБК', 'АС ЕРИБ', 'АС Транзакт', 'АС ФС', 'АС СПООБК', 'АС ЦОД',
#        nan, 'Билинг Сбербанк-Телекома', 'АС ЕФС', 'АС БС', 'АС ЕКП',
#        'АС ЕПС', 'САМОКАТ', 'СБЕРБОКС', 'ОККО', 'OSAGO', 'Сбермаркет',
#        'Реестры', 'ЦБДБО', 'CRM-Корпоративный', 'АС ЕКС+АС SM',
#        'Страховки ДЗО', 'СберУслуги', 'ДомКлик', 'BUSINESS_CARD',
#        'CRM_RKO_CHANGE'], dtype=object)

# %%
df1['OPERATION'].unique()
# Out:
# array(['Оформление подключения к услуге ',
#        'Оформление: Выписка по счету ДК/вклада/сбер счета/КК, Реквизиты, Выписка для госслужащих, Справка о доступном остатке, об уплаченных % ',
#        'Платеж по карте/счету (через СБОЛ) ',
#        'Прием документов на получение кредита ',
#        'Оформление заявления на выдачу банковских карт ',
#        'Оформление заявления на выдачу дебетовой банковской карты МИР Золотая зарплатная сотруднику бюджетного учреждения ',
#        'Выдача банковской карты ', 'Обновление данных клиентов ',
#        'Платеж по карте/счету (через FSB) ',
#        'Оформление заявления на выдачу личной дебетовой карты Сберкарта через СБОЛ ',
#        'Оформление ежемесячной подписки "СберПрайм +" ',
#        'Открытие вклада / ОМС ',
#        'Оформление и оплата годовой подписки "Сберпрайм" ',
#        'Оформление вклада On-line ',
#        'Оформление заявления на перевод заработной платы на счет, открытый в Сбербанке ',
#        'Реактивация Мобильного приложения СберБанк Онлайн + транзакционная активность (60+) (2 сценарий) ',
#        'Сервис "Сберлогистика": выдача посылки ',
#        'Подключение к услуге "Мобильный виртуальный оператор" с абонентской платой 0 (тариф "Старт") в рамках подписки "СберПрайм" ',
#        'Реактивация услуги ',
#        'Оформление заявления на выдачу дебетовой банковской карты Mastercard Сберкарта ',
#        'Подключение к услуге Мобильное приложение СберБанк Онлайн + транзакционная активность (30-59) (2 сценарий) ',
#        'Сбор согласий на использование биометрических данных ',
#        'Продажа страхового продукта ',
#        'Оформление заявления на перевод денежных средств на карту Социальная ',
#        'Выдача кредита ',
#        'Продажа продукта коробочного страхования – первый платеж ',
#        'Установка моб. прил. "СберМегаМаркет" с рег. по СберID и осущ. первого заказа в моб. прил. "СберМегаМаркет" в день проведения консул. ',
#        'Перевод по карте/счету (через FSB) ',
#        'Оформление документов на получение кредита по одновизитной технологии - оферте ',
#        'Обновление данных клиентов (УКО) ', 'Подписание УДБО ',
#        'Сервис "Самокат": установка мобильного приложения ',
#        'Добровольное страхование жизни и здоровья для держателей кредитных карт с риском диагностирования особо опасного заболевания ',
#        'Сбор биометрических данных ', 'Не премируется ',
#        'Открытие брокерского счета ПАО Сбербанк ',
#        'Оформление продукта "Kidsar" PULL механика (вне NBO) ',
#        'Оформление через СБОЛ заявления на выдачу банковских карт ',
#        'Продажа жилищного кредита / кредита под залог недвижимости (одобренная заявка) ',
#        'Заявление на открытие аккредитива ',
#        'Оформление ежемесячной подписки "Сберпрайм" по отдельной компании продаж клиентам на День рождения ',
#        'Открытие Номинального счета ',
#        'Прием через СБОЛ документов на получение кредита ',
#        'Непремируемые операции по пилоту 1122 ',
#        'Продукт "Аренда сейфов для хранения" ',
#        'Перевод по карте/счету (через СБОЛ) ',
#        'Оформление продукта "Телемедицина от ДокДок" ',
#        'Установка мобильного приложения ',
#        'Оформление Продукта на сайте Партнера ',
#        'Сервис "Сберлогистика": оформление и прием предоформленной посылки через СБОЛ или сайт ',
#        'Подключение к услуге Мобильное приложение СберБанк Онлайн + Обучение (60+) (2 сценарий) ',
#        'Подписка "Премиум" (12 месяцев) ',
#        'Подключение к услуге Мобильное приложение СберБанк Онлайн + Обучение (30-59) (2 сценарий) ',
#        'Оформление на бумаге заявления на выдачу банковских карт ',
#        'Оформление пакета услуг ', nan,
#        'Оформление заявления на выдачу предодобренной кредитной банковской карты (кроме карт Signature/Black Edition),учитываются выданные карты(Transact) ',
#        'Оформление заявления на перевод пенсии на карту Социальная, оформленное на бумаге (только для действующих клиентов) ',
#        'Реактивация Мобильного приложения СберБанк Онлайн + транзакционная активность (30-59) (2 сценарий) ',
#        'Прием документов на получение кредита (DomClick) ',
#        'Подписка "Оптимум на 1 мес." (витрина подарков) ',
#        'Открытие Обезличенного металлического счета ',
#        'Оформление заявления на выдачу зарплатной дебетовой банковской карты сотруднику Министерства обороны РФ ',
#        'Прием и оформление посылки - предоформленный возврат устройства через сайт ООО "СберДевайсы" ',
#        'Оформление заявления на выдачу личной дебетовой банковской карты Сберкарта, учитываются выданные карты (действующий клиент Банка) ',
#        'Сбор биометрического слепка Голос ',
#        'Пролонгация ежемесячной подписки "СберПрайм+" (оплата Клиентом подписки на второй месяц) ',
#        'Сервис "Сбер ЕАптека": осущ. первого заказа в моб. приложении "Сбер ЕАптека" в течение 30 дней после его установки на сумму от 500 рублей ',
#        'Подписка "Оптимум" (тариф за 39р) ',
#        'Продажа предодобренных кредитных Сберкарт ',
#        'Оформленный электронный полис ОСАГО ',
#        'Сервис "Сбермаркет": устан. сервиса и осущ. первого заказа в мобильном приложении "Сбермаркет" в течение 30 дней после его установки ',
#        'Открытие ОМС online ',
#        'Подключение к услуге Мобильное приложение СберБанк Онлайн + транзакционная активность (60+) (2 сценарий) ',
#        'Установка моб. прил. "СберМегаМаркет" с рег. по СберID и осущ. 1 заказа в моб. прил. "СберМегаМаркет" в течение 30 кал. дней с даты уст. Моб. ',
#        'Оформление заявления на перевод заработной платы на счет, открытый в Сбербанке (DSA) ',
#        'Реактивация Мобильного приложения СберБанк Онлайн + Обучение (30-59) (2 сценарий) ',
#        'Оформление Продукта на сайте Партнера (SberPortal) в канале ВСП по PULL механике (вне NBO) ',
#        'Продукт "Аккредитив в сделках с недвижимостью" ',
#        'Одобренная заявка на жилищный кредит, через сайт "ДомКлик" от клиента, которого МП зарегистрировал на "ДомКлик" ',
#        'Оформление через сайт Сбербанка заявления на выдачу банковских карт ',
#        'Подписка "Оптимум" (тариф за 39р) (платное действие) ',
#        'Продажа жилищного кредита / кредита под залог недвижимости (выдача кредита) ',
#        'Продажа через СБОЛ продукта коробочного страхования – первый платеж ',
#        'Сервис "Самокат": осуществление первого заказа в мобильном приложении "Самокат" в течение 30 дней после его установки ',
#        'Открытие инвестиционного счета ',
#        'Продажа продукта коробочного страхования – второй и последующие платежи ',
#        'Подключение программы "Страхование жизни заёмщиков Банка" клиенту с оформ. ранее страховым полисом в ООО СК "Сбербанк страх. жизни" ',
#        'Сервис "Сберлогистика": оформление и прием посылки ',
#        'Продажа продукта Индивидуальный пенсионный план – первый платеж ',
#        'Оформление сервиса "Назначение пенсии на Госуслугах" ',
#        'Оформление и оплата годовой подписки "СберПрайм+", в том числе с использованием промокода ',
#        'Продажа облигаций ПАО Сбербанк и Облигаций федерального займа ',
#        'Установка МП СберМегаМаркет из Личного кабинета "СберПрайм" с авторизацией по SberID ',
#        'Установка МП Сбер ЕАптека из Личного кабинета "СберПрайм" с авторизацией по SberID ',
#        'Оформление ежемесячной подписки "СберПрайм" (Фиджитал полка) ',
#        'Реактивация Мобильного приложения СберБанк Онлайн + Обучение (60+) (2 сценарий) ',
#        'Установка МП Сервиса "Самокат" с авториз. по SberID и осущ. 1-ого заказа в МП в течение 30 кален. дн. с даты установки МП ',
#        'Билет в будущее с ежемесячным взносом 3 500, 5 000 рублей. Расширенная/детская программа (мотив 1) ',
#        'Прием документов и подписание договора ОПС ',
#        'Открытие Расчетного счета RPA ',
#        'Установка моб. прил. "СберАвто" и осущ. Клиентом платного действия через сервис "СберАвто" в теч. 30 кал. дней после уст. моб. приложения ',
#        'Выдача кредитных банковских карт, оформленных Консультантами в мобильном приложении СБОЛ, WEB СБОЛ ',
#        'Открытие счета ГЖС ',
#        'Установка МП Самокат из Личного кабинета "СберПрайм" с авторизацией по SberID ',
#        'Подписка "Оптимум на 1 мес." (витрина подарков) (платное действие) ',
#        'Открытие индивидуального инвестиционного счета (стратегия "Российские акции") (ФМ) ',
#        'Оформление Продукта на сайте Партнера ("Sber.Box Top") ',
#        'Билет в будущее со средним взносом. Расширенная/детская программа (мотив 2) ',
#        'Открытие счета участника закупок ',
#        '2 целевое действие - переход от ежемесячной бесплатной подписки СБЕРПРАЙМ на ежемесячную платную подписку СБЕРПРАЙМ ',
#        'Установка МП Сервиса "Самокат" с авториз. по SberID и осущ. 1-ого заказа в МП в день проведения консул. ',
#        'Очная идентификация ФЛ - потенциальных ИП/ЕИО ООО (Деловая Среда) ',
#        'СМС-информирование по расчетному счету в рамках ПУ Легкий старт ',
#        'Паевые инвестиционные фонды (от 15 тыс. руб.) (ФМ) ',
#        'Индивидуальный пенсионный план Универсальный/ Активный капитал (ФМ) ',
#        'Открытие счета эскроу ',
#        'СМС-информирование по Бизнес-карте в рамках ПУ Легкий старт ',
#        'Продажа облигаций на вторичном рынке до 100 тыс.руб. (включительно) ',
#        'Продажа облигаций на вторичном рынке от 100 до 200 тыс.руб. (включительно) ',
#        'Оформление бизнес карты ЮЛ ',
#        'Продажа облигаций на вторичном рынке от 200 до 500 тыс.руб. (включительно) ',
#        'Оформленная услуга "Копирование документов клиента" в физической сети банка клиенту (6 и более листов копий) ',
#        '1 целевое действие - ежемесячная бесплатная подписка СБЕРПРАЙМ ',
#        'Оформление заявления на выдачу дебетовой банковской зарплатной карты сотруднику РЖД ',
#        'Открытие расчетного счета ЮЛ ',
#        'Оформление и оплата страхового полиса "Защита от клеща" в день обращения клиента в офис банка ',
#        'Оформленная услуга "Копирование документов клиента" в физической сети банка клиенту (1 - 5 листов копий) ',
#        'Продажа облигаций на вторичном рынке от 2 млн.руб. ',
#        'Подключение сервиса "Свое дело" ',
#        'Продажа облигаций на вторичном рынке от 500 до 1 000 тыс.руб. (включительно) ',
#        'Реактивация СберБанк Онлайн web + Обучение (30-59) (2 сценарий) ',
#        'Бизнес карта не в рамках ПУ при открытии счета ',
#        'Открытие Расчетного счета в АС ЕКС ',
#        'Реактивация СберБанк Онлайн web + транзакционная активность (30-59) (2 сценарий) ',
#        'РБиДОС – регистрация бизнеса ',
#        'Подключение программы "Страхование жизни заёмщиков Банка" клиенту с оформ. ранее страховым полисом в сторонней страховой компании ',
#        'Реактивация СберБанк Онлайн web + Обучение (60+) (2 сценарий) ',
#        'Платное действие в течение 30 дней ',
#        'Подключение программы "Страхование залогового имущества" клиенту с оформ. ранее страховым полисом в ООО СК "Сбербанк страхование" ',
#        'Продукт "Аренда сейфов для расчетов за счет собственных средств" ',
#        'Продажа облигаций на вторичном рынке от 1 до 2 млн.руб. (включительно) ',
#        'Подписка "Оптимум" (6 месяцев) ',
#        'Реактивация СберБанк Онлайн web + транзакционная активность (60+) (2 сценарий) ',
#        'Продажа жилищного кредита / кредита под залог недвижимости (РПГ) ',
#        'Выезд сотрудника для доставки бизнес-карты клиенту ',
#        'ОМС (золото, серебро, платина, палладий) Сумма инвестирования от 5 000 до 9 999 рублей ',
#        'ОМС (золото, серебро, платина, палладий) Сумма инвестирования от 10 000 рублей ',
#        'Подписка "Оптимум" (12 месяцев) ',
#        'Оформление и оплата страхового полиса "Питомец под защитой" в день консультации Клиента сотрудником банка ',
#        'Продажа предодобренных цифровых (Digital) кредитных банковских карт (РПГ) ',
#        'Оформление с 01.01.2019 через СБОЛ заявления на перевод пенсии на карту Социальная (DSA) ',
#        'Изменение категории клиента ',
#        'Оформление заявления на выдачу личной дебетовой банковской карты для пособий и пенсий, оформ. через СБОЛ, учит. выданные карты (РПГ) ',
#        'Продажа потребительского кредита (кроме жилищных и кредитов под залог недвижимости), оформленного через СБОЛ (РПГ) ',
#        'Перевод по ФИО и номеру телефона с выплатой наличными (через пункты Western Union) ',
#        'Продажа предодобренных КК Momentum, оформленных и выданных через СБОЛ.про ',
#        'Оформление Продукта на сайте Партнера (SberPortal) в канале внешней дистрибуции для контрольной группы ГОСБ ',
#        'Оформление и оплата страхового полиса "Фарм страхование" в день консультации Клиента сотрудником банка ',
#        'Накопительное страхование жизни (ФМ) ',
#        'Перевод по номеру телефона на карту/счёт, открытые в банке-партнёре ',
#        'Вклады online (РПГ) ',
#        'Подкл.прог."Страхование залогового имущества + расш. пакет защиты имущ." клиенту с оформ. ранее страх. полисом в ООО СК "Сбербанк страх." ',
#        'Выезд к Клиенту для внесения изменений в юридическое дело ',
#        'Оформление заявления о переводе зарплаты сотруднику Министерства обороны РФ ',
#        'Страховой конструк. 2 и более опции из перечня: Защита жизни, Защита здоровья, Защита от потери работы, Защита от снижения оклада (РПГ) ',
#        'РБиДОС – открытие счета ',
#        'Подключение опции "Выбор номера" при подключении услуги "Мобильный виртуальный оператор" (бронзовый номер) ',
#        'Установка МП Сервиса "СберМаркет" с авториз. по SberID и осущ. 1-ого заказа в МП в течение 30 кален. дн. с даты установки МП ',
#        'Билет в будущее с минимальным взносом. Расширенная/детская программа (мотив 2) ',
#        'Билет в будущее с ежемесячным взносом 2 000 рублей. Базовая программа (мотив 1) ',
#        'Установка МП Сервиса "СберМаркет" с авториз. по SberID и осущ. 1-ого заказа в МП в день проведения консул. ',
#        'Страховой конструктор. 1 опция из перечня: Защита жизни, Защита здоровья, Защита от потери работы, Защита от снижения оклада (РПГ) ',
#        'Билет в будущее с минимальным взносом. Базовая программа (мотив 2) ',
#        'Билет в будущее с ежемесячным взносом 10 000 рублей. Расширенная/детская программа (мотив 1) ',
#        'Билет в будущее с ежемесячным взносом 2 000 рублей. Расширенная/детская программа (мотив 1) ',
#        'Продажа СЭР ',
#        'Билет в будущее с максимальным взносом. Расширенная/детская программа (мотив 2) ',
#        'Билет в будущее со средним взносом. Базовая программа (мотив 2) ',
#        'Добровольное страхование жизни и здоровья для держателей кредитных карт (Подключение программы. Все виды) ',
#        '2 целевое действие - переход от ежемесячной бесплатной подписки СБЕРПРАЙМ на годовую платную подписку СБЕРПРАЙМ ',
#        'Билет в будущее с единовременным взносом 120 000 рублей. Расширенная/детская программа (мотив 1) ',
#        'Оформление Продукта "Управление умным домом" (Лампа Е14, Е27) - PULL механика (вне NBO) ',
#        'Доставка документов/ценностей клиентам Сбербанк Премьер ',
#        'Билет в будущее с ежемесячным взносом 3 500, 5 000 рублей. Базовая программа (мотив 1) ',
#        'Билет в будущее с единовременным взносом 210 000, 300 000 рублей. Базовая программа (мотив 1) ',
#        'Подписка "СберПрайм" 1 месяц (МНСС) ',
#        'Оформление Продукта "Управление умным домом" (розетка) PULL механика (вне NBO) ',
#        'Билет в будущее с единовременным взносом 210 000, 300 000 рублей. Расширенная/детская программа (мотив 1) ',
#        'Идентификация абонентов ',
#        'Инвестиционное страхование жизни (ФМ) ',
#        'Билет в будущее с единовременным взносом 120 000 рублей. Базовая программа (мотив 1) ',
#        'Подключение программы "Страхование залогового имущества" клиенту с оформ. ранее страховым полисом в сторонней страховой компании ',
#        'Билет в будущее с единовременным взносом 600 000, 1 000 000 рублей. Расширенная/детская программа (мотив 1) ',
#        'Оформление подписки "Сберпрайм" стоимостью 180 руб. за 180 дней ',
#        'Установка МП Сервиса "Сбер ЕАптека" с авториз. по SberID и осущ. 1-ого заказа в МП в день проведения консул. ',
#        'Выдача СберКарты Моментальной ',
#        'Открытие брокерского счета (ФМ) ',
#        'Оформленный электронный полис КАСКО (1294) ',
#        'Добровольное страхование жизни и здоровья для держателей кредитных карт (Активация) ',
#        'Оформление подписки "Сберпрайм" стоимостью 299 руб. за 6 месяцев ',
#        'Продажа кредитной банковской карты ',
#        'Оформление заявок на операционное обслуживание и подключение клиентов к продуктам АО "Уфанет" ',
#        'Билет в будущее с ежегодным взносом 24 000 рублей. Расширенная/детская программа (мотив 1) ',
#        'Подключение опции "Выбор номера" при подключении услуги "Мобильный виртуальный оператор" (серебряный номер) ',
#        'Оформление заявления на выдачу личной дебетовой банковской карты Сберкарта, учитываются выданные карты (действ-й клиент Банка)(РПГ) ',
#        'Продукт "Доктор онЛайн от СберЗдоровье" ',
#        'Продажа кредитных Сберкарт, оформленных через СБОЛ (РПГ) ',
#        'Билет в будущее с ежегодным взносом 24 000 рублей. Базовая программа (мотив 1) ',
#        'Еврооблигации (ФМ) '], dtype=object)

# %%
df1['CHANNEL_GR'].unique()
# Out:
# array(['ВСП', nan, 'ПРЕМЬЕР', 'ПРЯМЫЕ ПРОДАЖИ', 'ПАРТНЁРЫ',
#        'ПРЯМЫЕ ПРОДАЖИ(ЦОПП)', 'ВИП', 'ЭКВАЙРИНГ'], dtype=object)

# %%
df1['PRODUCT_NAME'].value_counts()
# Out:
# Потребительские кредиты (кроме кредита под залог недвижимости)                                                                                3141868
# Банковские карты                                                                                                                               976918
# Мобильный банк                                                                                                                                 866144
# Кредитные карты (стандартные)                                                                                                                  833873
# Дебетовые карты без овердрафта (зарплатные)                                                                                                    769727
# Дебетовая карта Сберкарта                                                                                                                      712669
# Платеж по карте/счету                                                                                                                          655375
# Личная дебетовая карта без овердрафта МИР Социальная                                                                                           496360
# Кредитные карты (предодобренные)                                                                                                               425972
# Ипотека                                                                                                                                        410988
# Личная дебетовая карта без овердрафта Visa Classic                                                                                             383047
# Личная дебетовая карта без овердрафта Сбербанк - Visa Electron «Momentum»                                                                      364937
# Вклады                                                                                                                                         349650
# Личная дебетовая карта без овердрафта Сбербанк - Maestro «Momentum»                                                                            292966
# Мобильное приложение СБОЛ                                                                                                                      292622
# Подписание УДБО                                                                                                                                255368
# Сервис "Сберлогистика"                                                                                                                         238710
# Продукт "Сберпрайм"                                                                                                                            230069
# Личная дебетовая карта без овердрафта MasterCard Standart                                                                                      212699
# Выписка по счету ДК/вклада/сбер счета/КК, Реквизиты, Выписка для госслужащих, Справка о доступном остатке, об уплаченных процентах             207064
# Данные клиентов                                                                                                                                155887
# Коробочное страхование банковских карт "Сбереги финансы" (Стоимость менее 2400)                                                                105982
# Согласие на использование биометрических данных                                                                                                 87579
# Добровольное страхование жизни и здоровья для держателей кредитных карт                                                                         85790
# Личная дебетовая карта Momentum/Мгновенной выдачи                                                                                               78825
# Добровольное страхование жизни на случай диагностирования критического заболевания                                                              70340
# СберМегаМаркет                                                                                                                                  64131
# Перевод по карте/счету                                                                                                                          61290
# Страхование заемщика (несколько видов кредита)                                                                                                  51122
# Биометрические данные                                                                                                                           41422
#                                                                                                                                                ...
# Кредитная банковская карта Signature/Black Edition                                                                                                 28
# Подключение к услуге "Мобильный виртуальный оператор", тариф "SberTeam"/ "SberTeam+"                                                               28
# Коробочное страхование банковских карт (стоимость 5940)                                                                                            28
# Коробочное страхование "Защита квартиры", "Защита дома" (стоимость 2250)                                                                           24
# Коробочное страхование банковских карт (стоимость 1980)                                                                                            23
# Инвестиционное страхование жизни                                                                                                                   23
# Оформление и оплата страхового полиса "Фарм страхование" в день консультации Клиента сотрудником банка                                             18
# Подключение к услуге "Мобильный виртуальный оператор" с абонентской платой (стоимость 600 – 1150)                                                  13
# Коробочное страхование банковских карт, оформленное через СБОЛ (стоимость 1290)                                                                    11
# Идентификация абонентов eSIM "Мобильного виртуального оператора"                                                                                   10
# Пакет услуг "Зарплатный +"                                                                                                                          7
# Коробочное страхование "Защита квартиры", "Защита дома" (стоимость 4950)                                                                            6
# Коробочное страхование банковских карт (стоимость 4200)                                                                                             6
# Оформление и оплата страхового полиса "Питомец под защитой" в день консультации Клиента сотрудником банка                                           5
# Сбер Услуги                                                                                                                                         5
# Выезд к Клиенту                                                                                                                                     4
# Кредитные карты Momentum (предодобренные)                                                                                                           4
# Доставка документов/ценностей клиентам Сбербанк Премьер                                                                                             3
# Личная дебетовая карта без овердрафта МИР Премиальная                                                                                               3
# СберЗдоровье (все продукты)                                                                                                                         2
# Перевод по номеру телефона                                                                                                                          2
# Коробочное страхование банковских карт (стоимость 3780)                                                                                             2
# Коробочное страхование банковских карт, оформленное через СБОЛ (стоимость 1190)                                                                     1
# Коробочное страхование "Защита от травм" страховая сумма от 400 000 до 600 000 (стоимость от 732) Базовое покрытие, квартальный платеж              1
# Продажа СЭР и СБР                                                                                                                                   1
# Коробочное страхование банковских карт (стоимость 6600)                                                                                             1
# Коробочное страхование "Защита от травм" страховая сумма от 600 000 и более (стоимость от 1 505) Расширенное покрытие, квартальный платеж           1
# Подключение к пакету услуг "Всегда на связи"                                                                                                        1
# Личная дебетовая карта без овердрафта Сбербанк – Maestro                                                                                            1
# Коробочное страхование "Личный юрист", тариф "Базовый"                                                                                              1
# Name: PRODUCT_NAME, Length: 167, dtype: int64

# %% [markdown]
# ### Добавляем некоторые сводные столбцы по количеству операций за период:

# %%
df1 = df1.merge(df1[['DATE_REPORT','EMPLOYEE_ID', 'ID_Operation_History']].groupby(['EMPLOYEE_ID','DATE_REPORT'], as_index=False).\
    agg({'ID_Operation_History':'count'}).rename(columns={'ID_Operation_History':'emp_oper_per_day'}), on=['DATE_REPORT','EMPLOYEE_ID'], how='left')
df1 = df1.merge(df1[['DATE_REPORT','untb', 'ID_Operation_History']].groupby(['untb','DATE_REPORT'], as_index=False).\
    agg({'ID_Operation_History':'count'}).rename(columns={'ID_Operation_History':'client_product_per_day'}), on=['DATE_REPORT','untb'], how='left')

# %%
time_series = df1[['DATE_REPORT', 'ID_Operation_History', 'EMPLOYEE_ID', 'untb']]
time_series['DATE_REPORT'] = pd.to_datetime(df1['DATE_REPORT'])
#time_series = time_series.set_index('DATE_REPORT')
time_series['month'] = time_series['DATE_REPORT'].dt.month
time_series['year'] = time_series['DATE_REPORT'].dt.year
df1['month'] = df1['DATE_MONTH'].dt.month
df1['year'] = df1['DATE_MONTH'].dt.year

# %%
df1 = df1.merge(time_series.groupby(['EMPLOYEE_ID', 'year', 'month'], as_index=False)[['ID_Operation_History']].count().\
          rename(columns={'ID_Operation_History':'emp_oper_per_month'}), on=['EMPLOYEE_ID', 'year', 'month'], how='left')

# %%
time_series.head()
# Out:
#   DATE_REPORT  ID_Operation_History  EMPLOYEE_ID        untb  month  year
# 0  2021-08-09              25664113     961677.0  26822468.0      8  2021
# 1  2021-08-18              25664134    1800908.0  21381134.0      8  2021
# 2  2021-08-13              25664157    1116607.0  20020401.0      8  2021
# 3  2021-08-17              25664169    1889942.0  11772029.0      8  2021
# 4  2021-08-23              25664176     389534.0   2986391.0      8  2021

# %% [markdown]
# ### Создаём dataset для обучения и добавляем в него признаки

# %%
df = pd.DataFrame() #dataset

# %%
df['ID_Operation_History'] = df1['ID_Operation_History']
df['date_report'] = pd.to_datetime(df1['DATE_REPORT']).dt.day
df['emploee_position'] = df1['EMPLOYEE_POSITION']
df['emp_age'] = (df1['DATE_REPORT'] - df1['EBIRTH']) / dt.timedelta(days=365)
df['report-start_job'] = (df1['DATE_REPORT'] - df1['RBEGDA']).dt.days
df['finish_job-report'] = (df1['RENDDA'] - df1['DATE_REPORT']).dt.days
df['SOURCE_SYSTEM'] = df1['SOURCE_SYSTEM']
df['OPERATION'] = df1['OPERATION']
df['CHANNEL_GR'] = df1['CHANNEL_GR']
df['urf_code_uni'] = df1['urf_code_uni']
df['QUANTITY'] = df1['QUANTITY']
df['DESCRIPTION'] = df1['DESCRIPTION']
df['IN_MOTIV'] = df1['IN_MOTIV']
df['PRODUCT_NAME'] = df1['PRODUCT_NAME']
df['vl_up'] = df1['vl_up']
df['insert-report'] = (df1['insert_date'] - df1['DATE_REPORT']).dt.days
df['update-report'] = (df1['DATE_UPDATE'] - df1['DATE_REPORT']).dt.days
df['client_age'] = (df1['DATE_REPORT'] - df1['birth']) / dt.timedelta(days=365)
df['client_is_emploee'] = np.where(df1['Табельный_клиента'].isnull(), 0, 1)
df['emploee_in_vacation'] = np.where(df1['Отпуск'].isnull(), 0, 1)
df['emp_oper_per_day'] = df1['emp_oper_per_day']
df['emp_oper_per_month'] = df1['emp_oper_per_month']
df['day_of_week'] = pd.to_datetime(df1['DATE_REPORT']).dt.weekday_name
df['client_product_per_day'] = df1['client_product_per_day']
df['target'] = df1['IS_FRAUD']

# %%
df['target'] = df1['IS_FRAUD']

# %%
#df.to_csv('dataset_1.csv')

# %%
df = pd.read_csv('dataset_1.csv')

# %% [markdown]
# Не добавленный признак с первого раза, нужно переписать

# %%
time_series['client_product_at_moment'] = time_series[['DATE_REPORT', 'untb']].progress_apply(lambda x: time_series[(time_series['DATE_REPORT'] < x[0])
                                                                          &(time_series['untb'] == x[1])]['ID_Operation_History'].count(), axis=1)
# Out:
#   0%|          | 0/13397810 [00:00<?, ?it/s]

# %%
#df['client_product_at_moment']= time_series['client_product_at_moment']

# %% [markdown]
# ### Количество уже имеющихся продуктов у человека на момент продажи нового продукта за 181 день:

# %%
clprod = pd.read_csv('client_product_since20210101.csv', sep=';')
clprod['DATE_REPORT'] = pd.to_datetime(clprod['DATE_REPORT'])

# %%
clprod = clprod.groupby(['DATE_REPORT','untb'], as_index=False).agg({'ID_Operation_History':'count'})

# %%
day_oper = time_series.groupby(['DATE_REPORT','untb'], as_index=False).agg({'ID_Operation_History':'count'})

# %%
day_oper['DATE_REPORT'][0] - dt.datetime(2021, 1, 1, 0, 0,0)
# Out:
# Timedelta('181 days 00:00:00')

# %%
clprod.dtypes
# Out:
# DATE_REPORT             datetime64[ns]
# untb                             int64
# ID_Operation_History             int64
# dtype: object

# %%
dates = day_oper['DATE_REPORT'].drop_duplicates()

# %%
day_oper = pd.concat([clprod, day_oper])

# %%
day_oper
# Out:
#         DATE_REPORT        untb  ID_Operation_History
# 0        2021-01-01    173475.0                     1
# 1        2021-01-01    174525.0                     1
# 2        2021-01-01    175934.0                     1
# 3        2021-01-01    177232.0                     1
# 4        2021-01-01    177648.0                     1
# ...             ...         ...                   ...
# 8050384  2021-12-31  47341427.0                     4
# 8050385  2021-12-31  47341437.0                     6
# 8050386  2021-12-31  47341445.0                     6
# 8050387  2021-12-31  47346703.0                     2
# 8050388  2021-12-31  47363534.0                     1
#
# [15434360 rows x 3 columns]

# %%
dates.iloc[0] - dt.timedelta(181)
# Out:
# Timestamp('2021-01-01 00:00:00')

# %%
df1['DATE_REPORT'] = pd.to_datetime(df1['DATE_REPORT'])
#client_product = df1[['ID_Operation_History', 'DATE_REPORT', 'untb']].merge(oper_data, on=['DATE_REPORT', 'untb'], how='inner')

# %%
oper_data = pd.DataFrame()
oper_per_data = pd.DataFrame()
for date in tqdm(dates):
    oper_per_data = day_oper[(day_oper['DATE_REPORT'] < date)&(day_oper['DATE_REPORT'] >= date - dt.timedelta(181))].\
                           groupby('untb', as_index=False).agg({'ID_Operation_History':'sum'})
    oper_per_data['DATE_REPORT'] = date
    oper_per_data = df1[['ID_Operation_History','untb']][df1['DATE_REPORT'] == date].merge(oper_per_data, on='untb', how='inner')
    oper_data = pd.concat([oper_data, oper_per_data])
# Out:
#   0%|          | 0/184 [00:00<?, ?it/s]

# %%
oper_data
# Out:
#        ID_Operation_History_x        untb  ID_Operation_History_y DATE_REPORT
# 0                    19812303  46400017.0                       5  2021-07-01
# 1                    20942271  46400017.0                       5  2021-07-01
# 2                    19823247  46400017.0                       5  2021-07-01
# 3                    19867023  46400017.0                       5  2021-07-01
# 4                    19871127  46400017.0                       5  2021-07-01
# ...                       ...         ...                     ...         ...
# 16222                52691206   9813184.0                       2  2021-12-31
# 16223                52826735  33881746.0                       6  2021-12-31
# 16224                52925755  30270978.0                       2  2021-12-31
# 16225                52931048  32924220.0                       3  2021-12-31
# 16226                52935848  40987524.0                       2  2021-12-31
#
# [9324352 rows x 4 columns]

# %%
oper_data = oper_data.rename(columns={'ID_Operation_History_y': 'client_product_at_moment', 'ID_Operation_History_x': 'ID_Operation_History'})

# %%
oper_data.to_csv('product_at_moment.csv')

# %% [markdown]
# Старый способ (ещё более долгий):

# %%
time_series[(time_series['DATE_REPORT'] < pd.datetime(2021, 8, 13))&(time_series['untb'] == 20020401.0)]['ID_Operation_History'].count()
# Out:
# 2

# %% [markdown]
# # Emploee info & client info

# %%
emp = pd.read_csv('Emp_info.csv', sep=';')

# %%
client = pd.read_csv('client_info.csv', sep=';')

# %% [markdown]
# #### Emploee

# %%
emp = emp[['EMPLOYEE_FIO', 'EBIRTH', 'emploee_ActAddress', 'emploee_BirthPlace',
       'emploee_DateUnseeing', 'emploee_DeathDay', 'emploee_FLAG_AGENT',
       'emploee_FLAG_EXIST_AGENT', 'emploee_Literate',
       'emploee_PENSIONER_DATE', 'emploee_Resident', 'emploee_Sex',
       'emploee_Unseeing']].drop_duplicates()

# %%
emp['emploee_DeathDay'] = emp['emploee_DeathDay'].fillna('1800-01-01')
emp['emploee_PENSIONER_DATE'] = emp['emploee_PENSIONER_DATE'].fillna('2262-01-01')
emp['emploee_Sex'] = emp['emploee_Sex'].fillna(0)
emp['EBIRTH'] = emp['EBIRTH'].fillna('1700-1-1')
emp['EMPLOYEE_FIO'] = emp['EMPLOYEE_FIO'].fillna('-')
emp['emploee_FLAG_AGENT'] = emp['emploee_FLAG_AGENT'].fillna(0)
emp['emploee_FLAG_EXIST_AGENT'] = emp['emploee_FLAG_EXIST_AGENT'].fillna(0)

# %%
emp['EBIRTH'] = pd.to_datetime(emp['EBIRTH']).dt.date
emp['emploee_DeathDay'] = pd.to_datetime(emp['emploee_DeathDay']).dt.date
emp['emploee_PENSIONER_DATE'] = pd.to_datetime(emp['emploee_PENSIONER_DATE']).dt.date

# %%
df1 = df1.merge(emp[['EMPLOYEE_FIO', 'EBIRTH', 'emploee_DeathDay', 'emploee_FLAG_AGENT',
       'emploee_FLAG_EXIST_AGENT', 'emploee_PENSIONER_DATE', 'emploee_Resident', 'emploee_Sex']], on=['EMPLOYEE_FIO', 'EBIRTH'], how='left')

# %%
df = df.merge(df1[['ID_Operation_History', 'emploee_DeathDay', 'emploee_FLAG_AGENT',
       'emploee_FLAG_EXIST_AGENT', 'emploee_PENSIONER_DATE', 'emploee_Resident', 'emploee_Sex']], on='ID_Operation_History', how='left')

# %%
emp.head()
# Out:
#                     EMPLOYEE_FIO      EBIRTH  \
# 0         Абазян Яна Анатольевна  1990-03-15
# 1      Абаимова Мария Васильевна  1990-07-11
# 2   Абакумов Александр Сергеевич  1985-02-03
# 11    Абакумова Анаита Сергеевна  1988-11-10
# 15    Абакумова Анаита Сергеевна  1988-11-10
#
#                                    emploee_ActAddress  \
# 0   692342!ПРИМОРСКИЙ!!!7!АРСЕНЬЕВ!44!ОКТЯБРЬСКАЯ!...
# 1      443000 Г. САМАРА, УЛ. СОЛНЕЧНАЯ Д. 15 КВ. 123
# 2   629307!ЯМАЛО-НЕНЕЦКИЙ!!!7!НОВЫЙ УРЕНГОЙ!48!ГУБ...
# 11  628602!АО ХАНТЫ-МАНСИЙСКИЙ АВТОНОМНЫЙ ОКРУГ - ...
# 15  644080!ОБЛ ОМСКАЯ!05!СЕДЕЛЬНИКОВСКИЙ!10!СЕДЕЛЬ...
#
#                               emploee_BirthPlace emploee_DateUnseeing  \
# 0                  ГОР. АРСЕНЬЕВ ПРИМОРСКИЙ КРАЙ           1800-01-01
# 1                                   ГОР.КУЙБЫШЕВ           1800-01-01
# 2                                         Г ОМСК           1800-01-01
# 11  С. СТРОКИНО КОЛОСОВСКИЙ РАЙОН ОМСКАЯ ОБЛАСТЬ           1800-01-01
# 15  С. СТРОКИНО КОЛОСОВСКИЙ РАЙОН ОМСКАЯ ОБЛАСТЬ           1800-01-01
#
#    emploee_DeathDay  emploee_FLAG_AGENT  emploee_FLAG_EXIST_AGENT  \
# 0        1800-01-01                 0.0                       0.0
# 1        1800-01-01                 0.0                       0.0
# 2        1800-01-01                 0.0                       0.0
# 11       1800-01-01                 0.0                       0.0
# 15       1800-01-01                 0.0                       0.0
#
#     emploee_Literate emploee_PENSIONER_DATE  emploee_Resident  emploee_Sex  \
# 0                1.0             2262-01-01                 1          2.0
# 1                NaN             2262-01-01                 1          2.0
# 2                1.0             2262-01-01                 1          1.0
# 11               1.0             2262-01-01                 1          2.0
# 15               1.0             2262-01-01                 1          2.0
#
#     emploee_Unseeing
# 0                2.0
# 1                NaN
# 2                2.0
# 11               2.0
# 15               2.0

# %%
emp[['EMPLOYEE_FIO', 'EBIRTH']].drop_duplicates()
# Out:
#                              EMPLOYEE_FIO      EBIRTH
# 0                  Абазян Яна Анатольевна  1990-03-15
# 1               Абаимова Мария Васильевна  1990-07-11
# 2            Абакумов Александр Сергеевич  1985-02-03
# 11             Абакумова Анаита Сергеевна  1988-11-10
# 17             Абакумова Елена Викторовна  1989-10-12
# 18           Абакумова Елена Владимировна  1971-10-21
# 21            Абакумова Наталья Сергеевна  1990-02-27
# 25             Абалова Татьяна Алексеевна  1996-01-07
# 29           Абалтусова Вера Вениаминовна  1969-02-18
# 32              Абанина Любовь Васильевна  1961-07-23
# 53              Абасова Светлана Игоревна  1989-04-21
# 57      Абатурова Анастасия Станиславовна  1994-08-04
# 60           Абашева Екатерина Эдуардовна  1991-10-29
# 61             Абашина Людмила Михайловна  1963-08-05
# 66            Аббазова Гульнара Абдуловна  1984-11-26
# 85             Аббасова Шафига Рахим Кызы  1991-04-20
# 87             Абдалова Ксения Николаевна  1994-06-15
# 95            Абдразакова Дина Рустямовна  1983-02-02
# 101            Абдрахимова Дина Маратовна  1981-08-14
# 122         Абдрахимова Миляуша Саматовна  1991-04-12
# 127     Абдрахманова Лариса Фасхетдиновна  1984-10-06
# 133         Абдрахманова Насима Агзамовна  1992-05-24
# 156       Абдрахманова Вероника Радиковна  2002-07-30
# 164      Абдрахманова Танчулпан Винеровна  1992-05-14
# 165        Абдрахманова Эльвира Рашитовна  1998-07-29
# 167           Абдрахманова Юлия Ренатовна  1991-03-09
# 172        Абдрашитова Айгуль Салаватовна  1989-12-19
# 173          Абдрашитова Айселу Наильевна  1994-06-13
# 180          Абдрашитова Влада Рустамовна  1997-12-11
# 183           Абдрашитова Лилия Зуфаровна  1990-08-03
# ...                                   ...         ...
# 112404          Яхина Светлана Алексеевна  1987-05-11
# 112407              Яхина Элина Динаровна  1993-09-15
# 112411        Яхинова Гульсина Зиннуровна  1989-12-09
# 112417             Яхновец Яна Николаевна  1985-03-16
# 112419            Яцевич Ирина Леонидовна  1993-06-27
# 112420              Яцин Артем Николаевич  1995-05-29
# 112425              Яцина Олеся Андреевна  1997-10-10
# 112429         Яцкова Елена Александровна  1987-01-18
# 112452               Яцун Елена Фанилевна  1972-03-27
# 112456               Яцун Юлия Евгеньевна  1998-06-22
# 112460    Ячменева Светлана Александровна  1969-04-01
# 112463       Ячменева Светлана Михайловна  1981-02-18
# 112464             Яшин Владимир Игоревич  1993-03-07
# 112467             Яшин Сергей Алексеевич  1999-08-25
# 112490                 Яшин Яков Павлович  1999-04-10
# 112491           Яшина Валерия Валерьевна  1994-05-10
# 112499           Яшина Татьяна Викторовна  1988-06-21
# 112504         Яшкельдина Луиза Ралифовна  1985-03-28
# 112507             Яшкин Айдар Шалабаевич  1992-01-30
# 112508            Яшкин Игорь Геннадьевич  1988-12-03
# 112536              Яшкина Ирина Олеговна  1991-07-28
# 112538              Яшкина Самал Бакиевна  1991-04-26
# 112541         Яшмурзина Ирина Викторовна  1986-08-16
# 112542        Яшникова Людмила Михайловна  1989-05-22
# 112585       Ярославцева Елена Алексеевна  1986-02-08
# 112615      Ясакова Татьяна Александровна  1984-03-07
# 112658         Ятова Анастасия Алексеевна  2002-04-03
# 112679              Яхина Гулли Камилевна  1994-12-11
# 112760        Яшугина Ольга Александровна  1989-02-12
# 112761      Ященко Светлана Александровна  1978-01-09
#
# [15828 rows x 2 columns]

# %%
client = client.drop(['DEPOSIT_Balance', 'DEPOSIT_BranchNo', 'DEPOSIT_Office', 'DEPOSIT_OpCash', 'DEPOSIT_OpenDay', 'DEPOSIT_OpNo'], axis=1).drop_duplicates()

# %%
client['PERSON_DeathDay'] = client['PERSON_DeathDay'].fillna('1800-01-01')
client['PERSON_PENSIONER_DATE'] = client['PERSON_PENSIONER_DATE'].fillna('2262-01-01')
client['PERSON_Sex'] = client['PERSON_Sex'].fillna(0)
client['PERSON_FLAG_AGENT'] = client['PERSON_FLAG_AGENT'].fillna(0)
client['PERSON_FLAG_EXIST_AGENT'] = client['PERSON_FLAG_EXIST_AGENT'].fillna(0)

# %%
client['PERSON_Resident'].unique()
# Out:
# array([ 1.0000e+00,  2.0000e+00,  0.0000e+00,         nan, -2.9152e+04])

# %%
key = pd.read_csv('Key_for_client.csv', sep=';')

# %%
client = key.merge(client[['Номер_счёта_клиента','PERSON_DeathDay', 'PERSON_FLAG_AGENT', 'PERSON_FLAG_EXIST_AGENT',
                  'PERSON_PENSIONER_DATE', 'PERSON_Resident', 'PERSON_Sex']], on='Номер_счёта_клиента', how='left')

# %%
client = client.drop('Номер_счёта_клиента', axis=1)

# %%
df = df.merge(client, on='ID_Operation_History', how='left')

# %%
client.head()
# Out:
#    ID_Operation_History PERSON_DeathDay  PERSON_FLAG_AGENT  \
# 0              22824803      1800-01-01                0.0
# 1              22836703      1800-01-01                0.0
# 2              21824382      1800-01-01                0.0
# 3              21824382      1800-01-01                0.0
# 4              22836793      1800-01-01                0.0
#
#    PERSON_FLAG_EXIST_AGENT PERSON_PENSIONER_DATE  PERSON_Resident  PERSON_Sex
# 0                      0.0            2262-01-01              1.0         2.0
# 1                      0.0            2262-01-01              1.0         2.0
# 2                      0.0            2262-01-01              1.0         2.0
# 3                      0.0            2262-01-01              1.0         2.0
# 4                      0.0            2262-01-01              1.0         1.0

# %% [markdown]
# # FIN

# %%
clemp = pd.read_csv('Cl_to_emp.csv', sep=';',thousands=',')

# %%
clemp
# Out:
#         ID_Operation_History   Номер_счёта_клиента   emploee_PRINTABLENO  \
# 0                   20704900  40817810032003530693  40817810532008969989
# 1                   20938828  40817810032003530693  40817810532008969989
# 2                   21377956  40817810032003530693  40817810532008969989
# 3                   42800836  40817810032003530693  40817810532008969989
# 4                   42819988  40817810032003530693  40817810532008969989
# ...                      ...                   ...                   ...
# 397447              43538223  40817810432003536077  40817810432001278463
# 397448              44914299  40817810372003263603  40817810472004097804
# 397449              45692479  40817810532001233162  40817810032001233251
# 397450              46664965  40817810916547152578  40817810516541606789
# 397451              47084766  40817810132007062465  40817810632000911372
#
#          OPER_DATE  OPER_AMT
# 0       2020-01-01      1000
# 1       2020-01-01      1000
# 2       2020-01-01      1000
# 3       2020-01-01      1000
# 4       2020-01-01      1000
# ...            ...       ...
# 397447  2021-12-31      1000
# 397448  2021-12-31      4000
# 397449  2021-12-31       154
# 397450  2021-12-31       100
# 397451  2021-12-31      5000
#
# [397452 rows x 5 columns]

# %%
clemp = clemp.merge(df1[['ID_Operation_History', 'DATE_REPORT']], on='ID_Operation_History', how='left')

# %%
clemp['DATE_REPORT'] = pd.to_datetime(clemp['DATE_REPORT'])
clemp['OPER_DATE'] = pd.to_datetime(clemp['OPER_DATE'])
clemp['OPER_AMT'] = clemp['OPER_AMT'].astype('float')

# %%
clemp['clemp_diff_dates_before'] = clemp['DATE_REPORT'] - clemp['OPER_DATE']
clemp['clemp_diff_dates_after'] = clemp['OPER_DATE'] - clemp['DATE_REPORT']

# %%
clemp.loc[clemp['clemp_diff_dates_before'] < dt.timedelta(0), ['clemp_diff_dates_before']] = dt.timedelta(100_000)
clemp.loc[clemp['clemp_diff_dates_after'] < dt.timedelta(0), ['clemp_diff_dates_after']] = dt.timedelta(100_000)

# %%
clemp.dtypes
# Out:
# ID_Operation_History                 int64
# Номер_счёта_клиента                 object
# emploee_PRINTABLENO                 object
# OPER_DATE                   datetime64[ns]
# OPER_AMT                           float64
# DATE_REPORT                 datetime64[ns]
# diff_dates_before          timedelta64[ns]
# diff_dates_after           timedelta64[ns]
# clemp_diff_dates_before    timedelta64[ns]
# clemp_diff_dates_after     timedelta64[ns]
# dtype: object

# %%
clemp = clemp[['ID_Operation_History', 'OPER_AMT', 'clemp_diff_dates_before', 'clemp_diff_dates_after']].\
        groupby('ID_Operation_History', as_index=False).agg({'OPER_AMT':'sum', 'clemp_diff_dates_before':'min', 'clemp_diff_dates_after': 'min'})

# %%
clemp.rename(columns={'OPER_AMT':'clemp_amt'}).to_csv('clemp_data.csv')

# %% [markdown]
# Аналогично с переводами сотрудник - клиенту

# %%
empcl = pd.read_csv('emp_to_cl.csv', sep=';',thousands=',')

# %%
empcl
# Out:
#         ID_Operation_History   Номер_счёта_клиента   emploee_PRINTABLENO  \
# 0                   19785287  40817810872002705840  40817810772003681322
# 1                   19793495  40817810872002705840  40817810772003681322
# 2                   19851677  40817810316545275280  40817810616545275032
# 3                   19882978  40817810572333900339  40817810772008497799
# 4                   19918108  40817810806003188176  40817810606000446817
# ...                      ...                   ...                   ...
# 448723              20244529  40817810306003391311  40817810306006094770
# 448724              24029897  40817810967450152068  40817810467450297397
# 448725              42021721  40817810306003391311  40817810306006094770
# 448726              42174950  40817810406002877820  40817810506008903216
# 448727              44630510  40817810406002877820  40817810506008903216
#
#          OPER_DATE  OPER_AMT
# 0       2020-06-01     10000
# 1       2020-06-01     10000
# 2       2020-06-01      5000
# 3       2020-06-01      1000
# 4       2020-06-01      4300
# ...            ...       ...
# 448723  2021-09-14       300
# 448724  2021-09-14       500
# 448725  2021-09-14       300
# 448726  2021-09-14       202
# 448727  2021-09-14       202
#
# [448728 rows x 5 columns]

# %%
empcl = empcl.merge(df1[['ID_Operation_History', 'DATE_REPORT']], on='ID_Operation_History', how='left')

# %%
empcl['DATE_REPORT'] = pd.to_datetime(empcl['DATE_REPORT'])
empcl['OPER_DATE'] = pd.to_datetime(empcl['OPER_DATE'])
empcl['OPER_AMT'] = empcl['OPER_AMT'].astype('float')

# %%
empcl['empcl_diff_dates_before'] = empcl['DATE_REPORT'] - empcl['OPER_DATE']
empcl['empcl_diff_dates_after'] = empcl['OPER_DATE'] - empcl['DATE_REPORT']

# %%
empcl.loc[empcl['empcl_diff_dates_before'] < dt.timedelta(0), ['empcl_diff_dates_before']] = dt.timedelta(100_000)
empcl.loc[empcl['empcl_diff_dates_after'] < dt.timedelta(0), ['empcl_diff_dates_after']] = dt.timedelta(100_000)

# %%
empcl.dtypes
# Out:
# ID_Operation_History                 int64
# Номер_счёта_клиента                 object
# emploee_PRINTABLENO                 object
# OPER_DATE                   datetime64[ns]
# OPER_AMT                           float64
# DATE_REPORT                 datetime64[ns]
# empcl_diff_dates_before    timedelta64[ns]
# empcl_diff_dates_after     timedelta64[ns]
# dtype: object

# %%
empcl = empcl[['ID_Operation_History', 'OPER_AMT', 'empcl_diff_dates_before', 'empcl_diff_dates_after']].\
        groupby('ID_Operation_History', as_index=False).agg({'OPER_AMT':'sum', 'empcl_diff_dates_before':'min', 'empcl_diff_dates_after': 'min'})

# %%
empcl
# Out:
#        ID_Operation_History  OPER_AMT empcl_diff_dates_before  \
# 0                  19246082      10.0                287 days
# 1                  19251554      10.0                291 days
# 2                  19256560    6100.0                213 days
# 3                  19292271      10.0             100000 days
# 4                  19293073    1400.0                184 days
# ...                     ...       ...                     ...
# 53356              53225688   63887.0                109 days
# 53357              53225834    1000.0                377 days
# 53358              53225912   63887.0                109 days
# 53359              53226640     174.0                478 days
# 53360              53227034   33890.0                196 days
#
#       empcl_diff_dates_after
# 0                100000 days
# 1                100000 days
# 2                100000 days
# 3                    75 days
# 4                100000 days
# ...                      ...
# 53356            100000 days
# 53357            100000 days
# 53358            100000 days
# 53359            100000 days
# 53360            100000 days
#
# [53361 rows x 4 columns]

# %%
empcl.rename(columns={'OPER_AMT':'empcl_amt'}).to_csv('empcl_data.csv')
